# %%
#Anand.D_MY.AC.P2MCA25003
pwd
# Out:
# 'C:\\Users\\TEMP.AMRITAMYSORE.019'

# %%
try:
    print(x)
except:
    print("An exception occured")
# Out:
# An exception occured

# %%
try:
    a=int(input("Enter value a :"))
    b=int(input("Enter value b :"))
    print(a/b)
except ZeroDivisionError:
    print("An exception occured")
# Out:
# Enter value a : 5
# Enter value b : 0
# An exception occured

# %%
try:
    a=int(input("Enter value a :"))
    b=int(input("Enter value b :"))
    print(a/b)
except ValueError:
    print("Please enter a value integer")
except ZeroDivisionError:
    print("Cant be divisible by zero")
# Out:
# Enter value a : 5
# Enter value b :
# Please enter a value integer

# %%
try:
    print(x)
except NameError:
    print("Varibale x is not defined")
except:
    print("An exception occured")
# Out:
# Varibale x is not defined

# %%
try:
    num=int(input("Enter a num:"))
    res=100/num
    print(res)
except (ValueError,NameError,ZeroDivisionError) as error:
    print("Error",error)
# Out:
# Enter a num: 0
# Error division by zero

# %%
try:
    print("Hello")
except:
    print("Error")
else:
    print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
try:
    num=int(input("Enter a num:"))
    res=100/num
except ValueError:
    print("invalid input")
except ZeroDivisionError:
    print("Cant be divisible by zero")
else:
    print(res)
# Out:
# Enter a num: 5
# 20.0

# %%
try:
    f.open("std.txt",'w')
    try:
        f.write("Hello world")
    except:
        print("invalid input")
    finally:
        f.close()
except:
    print("smtg went wrong")
# Out:
# smtg went wrong

# %%
age=int(input("Enter age:"))
if age <0:
    raise ValueError("Age cannot be negative")
print("Age=",age)
# Out:
# Enter age: 20
# Age= 20

# %%
marks=int(input("Enter age:"))
if marks <0 or marks>100:
    raise ValueError("Age cannot be negative")
print("marks=",marks)
# Out:
# Enter age: 90
# marks= 90

# %%
age=int(input("Enter age:"))
assert age>=18
print("Elligible")
# Out:
# Enter age: 23
# Elligible

# %%
def cal_avg(marks):
    assert len(marks)>0,"Marks list cannot be empty "
    return sum(marks)/len(marks)
marks=[85,90,78,92,88]
print("Avg:",cal_avg(marks))
# Out:
# Avg: 86.6

# %%
class InvalidMarksError(Exception):
    pass
marks=int(input("Enter marks:"))
try:
    if marks<0 or marks>100:
        raise InvalidMarksError("Marks must be 0 to 100")
    print("Marks accepted",marks)
except InvalidMarksError as error:
    print("Error:",error)
# Out:
# Enter marks: 100
# Marks accepted 100
